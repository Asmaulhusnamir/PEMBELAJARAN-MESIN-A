# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/test (1).csv')
df1
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
df2 = df1.dropna()

# %%
df2
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
df2.describe()
# Out:
#                 x           y
# count  300.000000  300.000000
# mean    50.936667   51.205051
# std     28.504286   29.071481
# min      0.000000   -3.467884
# 25%     27.000000   25.676502
# 50%     53.000000   52.170557
# 75%     73.000000   74.303007
# max    100.000000  105.591837

# %%
import sklearn.model_selection as ms
x=df2[['x']]
y=df2[['y']]
X_train, X_test, y_train, y_test = ms.train_test_split(x,y,test_size=0.2, random_state=0)
print(X_train.size, X_test.size)
#20% menjadi test data dan 80%menjadi training data
# Out:
# 240 60

# %% [markdown]
# **Visualisasi**

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.scatter(X_train,y_train, edgecolors='y')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot antara x dan y')
x1 = np.linspace(0,106)
y1 = -0.53332421 + 1.0144497*x1
plt.plot(x1,y1)
plt.show()

# %%
import sklearn.linear_model as lm
model1 = lm.LinearRegression()
model1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model1.coef_
# Out:
# array([[1.0144497]])

# %%
model1.intercept_
#KETIKA MELEWATI SUMBU Y, DIA BERPOTONGAN DI TITIK -0,5
# Out:
# array([-0.53332421])

# %%
#Menguji model yang kita latih 
# bebas itu X, terikat itu Y
#r square menentukan seberap adekat model kita dengan garis
#r-square mendekati 1 itu bagus
#R^2 = 1-(RSS/TSS), data bagi garis linear
r2 = model1.score(X_test, y_test)
print(r2)
# Out:
# 0.9889794732637583

# %%
#prediksi diatas bagus karen amendekati 1
jarak = model1.predict([[50]])
print(jarak)
# Out:
# [[50.18916058]]
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
X_test
# Out:
#        x
# 208   67
# 188   27
# 12    96
# 221  100
# 239   28
# 136   65
# 230   37
# 206   40
# 52    52
# 108   89
# 290   92
# 15    15
# 184   37
# 248   90
# 22    89
# 74    15
# 270   55
# 90    67
# 229   14
# 164   49
# 190   92
# 103   74
# 124   41
# 129   29
# 222   48
# 116   17
# 194   61
# 286   16
# 234   65
# 295   71
# 92    63
# 66    41
# 8     20
# 122   98
# 219    4
# 150   60
# 176   58
# 182   93
# 299   47
# 5     15
# 223   42
# 89    43
# 81    27
# 34    28
# 55     0
# 139   53
# 236   56
# 64    82
# 7     95
# 45    37
# 73    53
# 213   44
# 173   56
# 106    1
# 59    57
# 253   60
# 168   21
# 26    79
# 284   59
# 153   84

# %%
prediksi = model1.predict(X_test)
print(prediksi)
# Out:
# [[ 67.43480541]
#  [ 26.85681758]
#  [ 96.8538466 ]
#  [100.91164538]
#  [ 27.87126727]
#  [ 65.40590602]
#  [ 37.00131454]
#  [ 40.04466362]
#  [ 52.21805998]
#  [ 89.75269872]
#  [ 92.79604781]
#  [ 14.68342123]
#  [ 37.00131454]
#  [ 90.76714842]
#  [ 89.75269872]
#  [ 14.68342123]
#  [ 55.26140906]
#  [ 67.43480541]
#  [ 13.66897153]
#  [ 49.17471089]
#  [ 92.79604781]
#  [ 74.53595329]
#  [ 41.05911332]
#  [ 28.88571697]
#  [ 48.16026119]
#  [ 16.71232062]
#  [ 61.34810724]
#  [ 15.69787092]
#  [ 65.40590602]
#  [ 71.4926042 ]
#  [ 63.37700663]
#  [ 41.05911332]
#  [ 19.75566971]
#  [ 98.88274599]
#  [  3.52447457]
#  [ 60.33365754]
#  [ 58.30475815]
#  [ 93.81049751]
#  [ 47.1458115 ]
#  [ 14.68342123]
#  [ 42.07356302]
#  [ 43.08801271]
#  [ 26.85681758]
#  [ 27.87126727]
#  [ -0.53332421]
#  [ 53.23250967]
#  [ 56.27585876]
#  [ 82.65155085]
#  [ 95.8393969 ]
#  [ 37.00131454]
#  [ 53.23250967]
#  [ 44.10246241]
#  [ 56.27585876]
#  [  0.48112548]
#  [ 57.29030845]
# ...

# %%
predicc = model1.predict([[67]])
print(predicc)
# Out:
# [[67.43480541]]
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
y_test
# Out:
#               y
# 208   68.488207
# 188   30.494129
# 12    95.149072
# 221  103.526616
# 239   28.156685
# 136   68.946998
# 230   40.007096
# 206   48.098431
# 52    54.081706
# 108   87.457216
# 290   91.308637
# 15    14.822486
# 184   34.124732
# 248   89.899991
# 22    89.826344
# 74    13.256906
# 270   55.816285
# 90    67.021506
# 229   12.426246
# 164   52.286206
# 190   89.731536
# 103   75.692986
# 124   45.445996
# 129   26.494880
# 222   47.410067
# 116   13.413108
# 194   60.071375
# 286   16.749239
# 234   66.614996
# 295   68.545888
# 92    58.614669
# 66    38.688887
# 8     18.395127
# 122   95.580172
# 219    7.646530
# 150   59.831397
# 176   57.487414
# 182   99.435779
# 299   52.459467
# 5      9.805235
# 223   42.038358
# 89    48.672526
# 81    23.444792
# 34    33.071128
# 55    -1.040114
# 139   60.207583
# 236   57.191035
# 64    85.455042
# 7     97.617937
# 45    36.113348
# 73    50.170086
# 213   45.963969
# 173   54.554470
# 106    0.275307
# ...

# %% [markdown]
# ##MENGGUBKANA LEBIH DARI 1 VARIABEL BEBA(MULTIPLE LINEAR REGRESSIONS)##

# %%
df = pd.read_csv('/content/kc_house_data.csv')

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
#agar pembuatan model tidak sia-sia, maka asumsinya dibenarkan. mislnya kalau ada variabel yang tidak berpengaruh sama skli maka bagusnya dibuang saja kek mantan
df.corr(method='pearson')
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
import pandas as pd
import numpy as np
import sklearn.model_selection as ms
import sklearn.linear_model as lm
X1 = df[['bathrooms', 'sqft_living']]
y1 = df[['price']]
X1_train, X1_test, y1_train, y1_test = ms.train_test_split(X1,y1,test_size=0.2, random_state=0)
print(X1_train.size, X1_test.size)
# Out:
# 34580 8646

# %%
model = lm.LinearRegression()
model.fit(X1_train, y1_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[-6095.34958438,   287.8115883 ]])

# %%
model.intercept_
# Out:
# array([-43344.28918513])

# %%
data1 = np.array([[3,2000]])
price = model.predict(data1)
print(price)
# Out:
# [[513992.8386712]]
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
r2 = model.score(X1_test, y1_test)
print (r2)
# Out:
# 0.4791133140827756

# %% [markdown]
# LOGISTIC REGRESSION

# %%
#simple gender classification
#https://www.kaggle.com/datasets/muhammadtalharasool/simple-gender-classification
df3 = pd.read_csv('/content/gender.csv')
df3
# Out:
#       Gender   Age   Height (cm)   Weight (kg)             Occupation  \
# 0       male    32           175            70      Software Engineer
# 1       male    25           182            85   Sales Representative
# 2     female    41           160            62                 Doctor
# 3       male    38           178            79                 Lawyer
# 4     female    29           165            58       Graphic Designer
# ..       ...   ...           ...           ...                    ...
# 126   female    32           170            64                  Nurse
# 127     male    38           176            79        Project Manager
# 128   female    27           162            55       Graphic Designer
# 129     male    33           175            77   Sales Representative
# 130   female    29           164            57     Software Developer
#
#          Education Level  Marital Status   Income (USD)  Favorite Color  \
# ...

# %%
#yang jadi y nya itu Gender
#import preprocessing
from sklearn import preprocessing
df3.head()
# Out:
#     Gender   Age   Height (cm)   Weight (kg)             Occupation  \
# 0     male    32           175            70      Software Engineer
# 1     male    25           182            85   Sales Representative
# 2   female    41           160            62                 Doctor
# 3     male    38           178            79                 Lawyer
# 4   female    29           165            58       Graphic Designer
#
#        Education Level  Marital Status   Income (USD)  Favorite Color  \
# 0      Master's Degree         Married          75000            Blue
# 1    Bachelor's Degree          Single          45000           Green
# 2     Doctorate Degree         Married         120000          Purple
# 3    Bachelor's Degree          Single          90000             Red
# 4   Associate's Degree          Single          35000          Yellow
#
#    Unnamed: 9
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0    Gender           131 non-null    object
#  1    Age              131 non-null    int64
#  2    Height (cm)      131 non-null    int64
#  3    Weight (kg)      131 non-null    int64
#  4    Occupation       131 non-null    object
#  5    Education Level  131 non-null    object
#  6    Marital Status   131 non-null    object
#  7    Income (USD)     131 non-null    int64
#  8    Favorite Color   131 non-null    object
#  9   Unnamed: 9        0 non-null      float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 10.4+ KB

# %%
df3.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'Occupation', 'Education',
#        'Married', 'Income', 'Favorite Color', 'Unnamed: 9'],
#       dtype='object')

# %%
df3.rename(columns=
          {" Gender": "Gender",
           " Age": "Age",
           " Height (cm)": "Height",
           " Weight (kg)": "Weight",
           " Occupation": "Occupation",
           " Education Level": "Education",
           " Favorite Color": "Favorite Color",
           " Marital Status": "Married",
           " Income (USD)": "Income"
          }
         ,inplace = True)

# %%
df3.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'Occupation', 'Education',
#        'Married', 'Income', 'Favorite Color', 'Unnamed: 9'],
#       dtype='object')

# %%
#Menjatuhkan kolom tanpa nama, tidak yakin apa yang diwakilinya.
df3.drop(labels = 'Unnamed: 9', axis = 1, inplace = True)

# %%
#Kita dapat melihat bahwa ada dua variabel untuk laki-laki dan perempuan, kita akan mengubahnya menjadi satu.
df3.Gender.value_counts()
# Out:
# male       41
# female     39
#  male      27
#  female    24
# Name: Gender, dtype: int64

# %%
df3.Gender.replace(to_replace = [" male", " female"],value = ["male","female"], inplace = True)

# %%
#Kami memiliki 68 laki-laki dan 63 perempuan dalam kumpulan data kami. Variabel target kami seimbang
df3.Gender.value_counts()
# Out:
# male      68
# female    63
# Name: Gender, dtype: int64

# %%
df3.isnull().sum()
# Out:
# Gender            0
# Age               0
# Height            0
# Weight            0
# Occupation        0
# Education         0
# Married           0
# Income            0
# Favorite Color    0
# dtype: int64

# %%
#Memindahkan variabel target Gender menjadi kolom terakhir
Gender = df3.pop("Gender")

# %%
df3.insert(8, 'Gender', Gender)

# %%
df3['Occupation'] = df3.Occupation.str.strip()

# %%
df3.Occupation.value_counts()
# Out:
# Teacher                 12
# Engineer                 9
# Writer                   9
# Doctor                   9
# Lawyer                   9
# Graphic Designer         9
# Marketing Specialist     9
# Project Manager          9
# Nurse                    9
# Sales Representative     7
# Architect                7
# IT Manager               7
# CEO                      6
# Accountant               6
# Analyst                  6
# Business Analyst         5
# Software Engineer        1
# Business Consultant      1
# Software Developer       1
# Name: Occupation, dtype: int64

# %%
#Menghapus semua spasi putih yang ada di kolom string.
for i in df3.columns:
    if df3[i].dtype == object:
        df3[i] = df3[""+i+""].str.strip()

# %%
df3["Favorite Color"].value_counts()
# Out:
# Blue      21
# Green     21
# Purple    17
# Red       17
# Yellow    16
# Black     12
# Orange    12
# Grey       8
# Pink       7
# Name: Favorite Color, dtype: int64

# %%
df3.head()
# Out:
#    Age  Height  Weight            Occupation           Education  Married  \
# 0   32     175      70     Software Engineer     Master's Degree  Married
# 1   25     182      85  Sales Representative   Bachelor's Degree   Single
# 2   41     160      62                Doctor    Doctorate Degree  Married
# 3   38     178      79                Lawyer   Bachelor's Degree   Single
# 4   29     165      58      Graphic Designer  Associate's Degree   Single
#
#    Income Favorite Color  Gender
# 0   75000           Blue    male
# 1   45000          Green    male
# 2  120000         Purple  female
# 3   90000            Red    male
# 4   35000         Yellow  female

# %%
#Mengubah variabel target menjadi 0 dan 1, dengan 1 mewakili laki-laki dan 0 mewakili perempuan
labelEncoder = preprocessing.LabelEncoder()
df3["Gender"] = labelEncoder.fit_transform(df3.Gender)

# %%
df3['Favorite Color'].hist()
# Out:
# <AxesSubplot:>

# %%
#Akan menghasilkan dummie vairables untuk data kategorikal yang ada
df3 = pd.get_dummies(df3, columns = ["Favorite Color", "Occupation", "Education", "Married"] )

# %%
df3.corr()
# Out:
#                                       Age    Height    Weight    Income  \
# Age                              1.000000  0.726308  0.784738  0.662278
# Height                           0.726308  1.000000  0.975157  0.456217
# Weight                           0.784738  0.975157  1.000000  0.486022
# Income                           0.662278  0.456217  0.486022  1.000000
# Gender                           0.652428  0.900727  0.931097  0.394992
# Favorite Color_Black             0.156337  0.266184  0.232088  0.050774
# Favorite Color_Blue              0.000480  0.025524  0.025400  0.153073
# Favorite Color_Green            -0.114687 -0.070528 -0.048910 -0.105023
# Favorite Color_Grey              0.023960 -0.006315 -0.006741 -0.058625
# Favorite Color_Orange            0.040931 -0.011166 -0.003142 -0.006627
# Favorite Color_Pink             -0.142070 -0.090584 -0.105617 -0.072448
# Favorite Color_Purple            0.142488  0.007443  0.027428  0.047886
# ...

# %%
pip install lazypredict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import lazypredict
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyClassifier

# %%
X3 = df3.drop("Gender",axis = 1)
y3 = df3["Gender"]

# %%
X3
# Out:
#      Age  Height  Weight  Income  Favorite Color_Black  Favorite Color_Blue  \
# 0     32     175      70   75000                     0                    1
# 1     25     182      85   45000                     0                    0
# 2     41     160      62  120000                     0                    0
# 3     38     178      79   90000                     0                    0
# 4     29     165      58   35000                     0                    0
# ..   ...     ...     ...     ...                   ...                  ...
# 126   32     170      64   60000                     0                    0
# 127   38     176      79   90000                     1                    0
# 128   27     162      55   55000                     0                    0
# 129   33     175      77   80000                     0                    0
# 130   29     164      57   65000                     0                    1
#
# ...

# %%
y3
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 126    0
# 127    1
# 128    0
# 129    1
# 130    0
# Name: Gender, Length: 131, dtype: int64

# %%
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, test_size = 0.23, random_state = 64)

# %% [markdown]
# Menguji semua model klasifikasi yang berbeda menggunakan lazypredict, sebuah library yang sangat membantu untuk membuat model pembelajaran mesin
#
# Perlu menurunkan semua nilai kolom ke skala yang sama, karena gaji memiliki nilai yang sangat besar.

# %%
sc = preprocessing.StandardScaler()
X3_train = sc.fit_transform(X3_train)
X3_test = sc.transform(X3_test)

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X3_train, X3_test, y3_train, y3_test)
models
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 14.67it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00     1.00      1.00
# BaggingClassifier                  1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# SVC                                1.00               1.00     1.00      1.00
# SGDClassifier                      1.00               1.00     1.00      1.00
# RidgeClassifierCV                  1.00               1.00     1.00      1.00
# RidgeClassifier                    1.00               1.00     1.00      1.00
# RandomForestClassifier             1.00               1.00     1.00      1.00
# Perceptron                         1.00               1.00     1.00      1.00
# PassiveAggressiveClassifier        1.00               1.00     1.00      1.00
# ...

# %% [markdown]
# Seperti yang bisa kita lihat, sebagian besar model telah bekerja sangat baik dengan akurasi 100%. Namun, kemungkinan besar model kami overfitting ke dataset kami karena kami memiliki dataset yang sangat kecil dengan hanya 130 nilai.
